# %% [markdown]
# # The E-commerce "Mega-Store" Analyzer
# **Focus Area**
# ***
# - Analyzing millions of transactions.
# - Use Pandas for complex `Group By` Operations
# - Use NumPy for high-performance vectorized maths such as calculating discounts, tax, and profit margins.

# %%
import numpy as np
import pandas as pd

# %%
quantities = np.random.randint(1, 11, 1000)
prices = np.random.uniform(10, 501, 1000)

# %% [markdown]
# ## 1. Creating the DataFrame

# %%
df = pd.DataFrame({'Quantity': quantities, 'Unit_Price': prices})
df
# Out:
#      Quantity  Unit_Price
# 0           8  464.168461
# 1           2  370.820986
# 2           2  186.850288
# 3           6  152.220618
# 4           7  253.019722
# ..        ...         ...
# 995         7  291.694608
# 996         8  235.810028
# 997         3  399.337111
# 998         1  492.057385
# 999         9  131.947564
#
# [1000 rows x 2 columns]

# %% [markdown]
# ## 2. Performing Vectorized Math

# %%
df['Total_Sales'] = df['Quantity'] * df['Unit_Price']
df
# Out:
#      Quantity  Unit_Price  Total_Sales
# 0           8  464.168461  3713.347687
# 1           2  370.820986   741.641972
# 2           2  186.850288   373.700576
# 3           6  152.220618   913.323709
# 4           7  253.019722  1771.138053
# ..        ...         ...          ...
# 995         7  291.694608  2041.862259
# 996         8  235.810028  1886.480223
# 997         3  399.337111  1198.011332
# 998         1  492.057385   492.057385
# 999         9  131.947564  1187.528074
#
# [1000 rows x 3 columns]

# %%
categories = ['Electronics', 'Clothing', 'Books', 'Beauty']
regions = ['North', 'South', 'East', 'West']
df['Category'] = np.random.choice(categories, size=1000)
df['Region'] = np.random.choice(regions, size=1000)
df
# Out:
#      Quantity  Unit_Price  Total_Sales     Category Region
# 0           8  464.168461  3713.347687     Clothing  South
# 1           2  370.820986   741.641972  Electronics  South
# 2           2  186.850288   373.700576       Beauty  North
# 3           6  152.220618   913.323709  Electronics  South
# 4           7  253.019722  1771.138053        Books   West
# ..        ...         ...          ...          ...    ...
# 995         7  291.694608  2041.862259  Electronics   East
# 996         8  235.810028  1886.480223        Books  South
# 997         3  399.337111  1198.011332  Electronics   East
# 998         1  492.057385   492.057385     Clothing  South
# 999         9  131.947564  1187.528074     Clothing   East
#
# [1000 rows x 5 columns]

# %% [markdown]
# ## 3. Exploratory Data Analysis (EDA)

# %%
# What is the total revenue for each category?
df.groupby('Category')['Total_Sales'].sum()
# Out:
# Category
# Beauty         371020.531688
# Books          317093.454943
# Clothing       375505.753931
# Electronics    382695.544256
# Name: Total_Sales, dtype: float64

# %% [markdown]
# ## 4. Multi-Metric Analysis

# %%
# The Total_Sales and the Average Quantity sold for each category at the same time.
df.groupby('Category').agg({'Total_Sales': 'sum', 'Quantity': 'mean'})
# Out:
#                Total_Sales  Quantity
# Category
# Beauty       371020.531688  5.714286
# Books        317093.454943  5.170732
# Clothing     375505.753931  5.652510
# Electronics  382695.544256  5.612000

# %% [markdown]
# ## 5. Data Cleaning

# %%
# Randomly setting 50 entries in Total_Sales to NaN
indices_to_hide = np.random.randint(0, 1000, 50)
df.loc[indices_to_hide, 'Total_Sales'] = np.nan 
df
# Out:
#      Quantity  Unit_Price  Total_Sales     Category Region
# 0           8  464.168461  3713.347687     Clothing  South
# 1           2  370.820986   741.641972  Electronics  South
# 2           2  186.850288   373.700576       Beauty  North
# 3           6  152.220618   913.323709  Electronics  South
# 4           7  253.019722  1771.138053        Books   West
# ..        ...         ...          ...          ...    ...
# 995         7  291.694608  2041.862259  Electronics   East
# 996         8  235.810028  1886.480223        Books  South
# 997         3  399.337111  1198.011332  Electronics   East
# 998         1  492.057385   492.057385     Clothing  South
# 999         9  131.947564          NaN     Clothing   East
#
# [1000 rows x 5 columns]

# %%
# Fill missing value using fillna method
df['Total_Sales'] = df['Total_Sales'].fillna(df['Total_Sales'].mean())
df
# Out:
#      Quantity  Unit_Price  Total_Sales     Category Region
# 0           8  464.168461  3713.347687     Clothing  South
# 1           2  370.820986   741.641972  Electronics  South
# 2           2  186.850288   373.700576       Beauty  North
# 3           6  152.220618   913.323709  Electronics  South
# 4           7  253.019722  1771.138053        Books   West
# ..        ...         ...          ...          ...    ...
# 995         7  291.694608  2041.862259  Electronics   East
# 996         8  235.810028  1886.480223        Books  South
# 997         3  399.337111  1198.011332  Electronics   East
# 998         1  492.057385   492.057385     Clothing  South
# 999         9  131.947564  1446.436189     Clothing   East
#
# [1000 rows x 5 columns]

# %% [markdown]
# ## 6. Data Filtering and Logic

# %%
# Which transactions were high-value (over $2000) and happened in the 'Electronics' category
df[(df['Category'] == 'Electronics') & (df['Total_Sales'] > 2000)]
# Out:
#      Quantity  Unit_Price  Total_Sales     Category Region
# 8           8  457.460059  3659.680473  Electronics   West
# 21          8  302.461068  2419.688546  Electronics  South
# 32          9  476.396569  4287.569122  Electronics  South
# 38          8  273.203453  2185.627625  Electronics  North
# 53          7  380.861298  2666.029085  Electronics  South
# ..        ...         ...          ...          ...    ...
# 916        10  499.626366  4996.263659  Electronics   West
# 919         8  274.818362  2198.546899  Electronics   East
# 938         7  392.967705  2750.773937  Electronics   East
# 942         7  383.499696  2684.497872  Electronics  North
# 995         7  291.694608  2041.862259  Electronics   East
#
# [74 rows x 5 columns]

# %% [markdown]
# ## 7. High-Performance Maths with NumPy
#
# **Create a Performance Score for every transaction**

# %%
# converting columns to NumPy arrays
sales = df['Total_Sales'].values
quantity = df['Quantity'].values
sales_std = np.std(sales)
df['Performance_Score'] = (df['Total_Sales'] * df['Quantity']) / sales_std;
df
# Out:
#      Quantity  Unit_Price  Total_Sales     Category Region  Performance_Score
# 0           8  464.168461  3713.347687     Clothing  South          25.842212
# 1           2  370.820986   741.641972  Electronics  South           1.290323
# 2           2  186.850288   373.700576       Beauty  North           0.650171
# 3           6  152.220618   913.323709  Electronics  South           4.767054
# 4           7  253.019722  1771.138053        Books   West          10.785109
# ..        ...         ...          ...          ...    ...                ...
# 995         7  291.694608  2041.862259  Electronics   East          12.433648
# 996         8  235.810028  1886.480223        Books  South          13.128537
# 997         3  399.337111  1198.011332  Electronics   East           3.126484
# 998         1  492.057385   492.057385     Clothing  South           0.428045
# 999         9  131.947564  1446.436189     Clothing   East          11.324418
#
# [1000 rows x 6 columns]

# %% [markdown]
# ## 8. Sorting and Ranking
# **List of the top 10 transactions based on the performance score**

# %%
df.sort_values(by='Performance_Score', ascending=False).head(10)
# Out:
#      Quantity  Unit_Price  Total_Sales     Category Region  Performance_Score
# 282        10  500.803207  5008.032070     Clothing   East          43.565348
# 916        10  499.626366  4996.263659  Electronics   West          43.462973
# 439        10  497.494029  4974.940292  Electronics  South          43.277479
# 627        10  481.151070  4811.510695       Beauty  North          41.855790
# 471        10  479.739580  4797.395801  Electronics  North          41.733003
# 199        10  476.163532  4761.635322       Beauty  South          41.421919
# 689        10  473.195797  4731.957966     Clothing   East          41.163753
# 834        10  465.385671  4653.856707       Beauty   East          40.484343
# 371        10  464.852422  4648.524224     Clothing  South          40.437955
# 498        10  459.487948  4594.879484       Beauty  South          39.971294

# %% [markdown]
# ## 9. Multi-Dimensional Analysis

# %%
# sum of total sales for each category across the different regions
pivot_tab = df.pivot_table(index='Category', columns='Region', values='Total_Sales', aggfunc='sum')
pivot_tab
# Out:
# Region                East         North          South           West
# Category
# Beauty        71287.804891  84927.543098  117404.282085  102919.093954
# Books         96047.988606  69072.258136   56627.872996  101119.351753
# Clothing      99306.485238  90275.701687   97153.593258   81052.559744
# Electronics  100538.621055  80556.339107  109999.015999   88147.677321

# %%
# include grand total for each row and column across all regions combined
df.pivot_table(index='Category', columns='Region', values='Total_Sales', aggfunc='sum', margins=True, margins_name='Total')
# Out:
# Region                East          North          South           West  \
# Category
# Beauty        71287.804891   84927.543098  117404.282085  102919.093954
# Books         96047.988606   69072.258136   56627.872996  101119.351753
# Clothing      99306.485238   90275.701687   97153.593258   81052.559744
# Electronics  100538.621055   80556.339107  109999.015999   88147.677321
# Total        367180.899789  324831.842029  381184.764339  373238.682771
#
# Region              Total
# Category
# Beauty       3.765387e+05
# Books        3.228675e+05
# Clothing     3.677883e+05
# Electronics  3.792417e+05
# Total        1.446436e+06

# %% [markdown]
# ## 10. Data Visualization

# %%
diagram = pivot_tab.iloc[:, :].plot(kind='bar', figsize=(10, 6))
diagram.legend(loc='upper right')
